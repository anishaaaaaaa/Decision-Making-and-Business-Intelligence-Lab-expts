# %% [markdown]
# Anisha Gharat
#
# BE Comps Batch E
#
# Roll no.: 68
#
# UID: 2018230071

# %% [markdown]
# # **WPM method**

# %%
RN = 68
N=93+RN%11
print("No. of Alternatives (N):",N)
M=70+RN%11
print("No. of Attributes (M):",M)
# Out:
# No. of Alternatives (N): 95
# No. of Attributes (M): 72

# %%
w=1
wi=w/M
print("Weights are (wi): ",wi)
# Out:
# Weights are (wi):  0.013888888888888888

# %%
lrange = RN//11
print("Start range: ",lrange)
rrange = RN+RN/11
print("End range: ",rrange)
# Out:
# Start range:  6
# End range:  74.18181818181819

# %%
import numpy as np
import pandas as pd

data = np.random.randint(lrange, rrange+1, size=(N, M))
df = pd.DataFrame(data, columns=[i for i in range(0,M)])
print("Dataset:")
df
# Out:
# Dataset:
#     0   1   2   3   4   5   6   7   8   ...  63  64  65  66  67  68  69  70  71
# 0    9   7  39  56  74  37  25  19  51  ...  47  57  67  56  70  60  14  38  25
# 1   74  31  16  11  51  55  42  51  56  ...  60  55   7  56  10  34  44  14  71
# 2   25  46   8  59  29  34  12  46  27  ...  22  59  45  63  17  61  67  49  58
# 3   73  69  28  12  18  23  64  38  41  ...  49  52  62   6  62  47  57   8  38
# 4   62   8  37  68  53  13  61  48  55  ...  54  72  52  64   8  58  48  44  21
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 90  65   9  60  40  26  58  19  62  13  ...  32  37  39  73  57  56  72  65  33
# 91  53  68  44  50  47  42  35  48  57  ...  46  56  34  21  74   7  62  24  51
# 92  12  22  21  23   9  36  60  60  34  ...  40  60  13  34  53  13  32  39  17
# 93  37  55  57  37  69  37  42   9  72  ...  13  58   8  46  64  16  43  57  29
# 94  53  49  54  11   8  52  55  64  43  ...  73  33  21  58  50  66  36  38  37
#
# [95 rows x 72 columns]

# %%
B = M//2
NB = M//2
print("No. of beneficial attributes (B) =",B)
print("No. of non-beneficial attributes (NB) =",NB)
# Out:
# No. of beneficial attributes (B) = 36
# No. of non-beneficial attributes (NB) = 36

# %%
arr=[]
for i in range(0,M):
  arr.append(i)

Bdata = np.random.randint(0,72,size=B)
#bdf = pd.DataFrame(Bdata, columns=['Beneficial Attributes'])

for i in range(0, len(Bdata)):
  if Bdata[i] in arr:
    arr.remove(Bdata[i])

print("Beneficial Attributes: ")
print(Bdata)
print()
print("Non-Beneficial Attributes: ",arr)
#nbdf = pd.DataFrame(arr, columns=['Non-Beneficial Attributes'])
# Out:
# Beneficial Attributes:
# [66 57 58 35 62 22 27 70 47 41 53 10  0 43 50 15 24  1 33 19 52 26 46 23
#  38 61 71 51 71 31 58  7 39 11  6 35]
#
# Non-Beneficial Attributes:  [2, 3, 4, 5, 8, 9, 12, 13, 14, 16, 17, 18, 20, 21, 25, 28, 29, 30, 32, 34, 36, 37, 40, 42, 44, 45, 48, 49, 54, 55, 56, 59, 60, 63, 64, 65, 67, 68, 69]

# %%
for i in arr:
  column = df[i]
  minval = column.min()
  #print(minval)
  df[i] = minval/df[i]
  # print(df[i])

# %%
for i in Bdata:
  column = df[i]
  maxval = column.max()
  #print(maxval)
  df[i] = maxval/df[i]
  # print(df[i])

# %%
print("Normalized matrix:")
df
# Out:
# Normalized matrix:
#           0          1         2   ...        69        70         71
# 0   8.222222  10.571429  0.153846  ...  0.500000  1.921053   4.166667
# 1   1.000000   2.387097  0.375000  ...  0.159091  5.214286  11.833333
# 2   2.960000   1.608696  0.750000  ...  0.104478  1.489796   9.666667
# 3   1.013699   1.072464  0.214286  ...  0.122807  9.125000   6.333333
# 4   1.193548   9.250000  0.162162  ...  0.145833  1.659091   3.500000
# ..       ...        ...       ...  ...       ...       ...        ...
# 90  1.138462   8.222222  0.100000  ...  0.097222  1.123077   5.500000
# 91  1.396226   1.088235  0.136364  ...  0.112903  3.041667   8.500000
# 92  6.166667   3.363636  0.285714  ...  0.218750  1.871795   2.833333
# 93  2.000000   1.345455  0.105263  ...  0.162791  1.280702   4.833333
# 94  1.396226   1.510204  0.111111  ...  0.194444  1.921053   6.166667
#
# [95 rows x 72 columns]

# %%
df = df**wi
print("Weighted Normalized decision matrix:")
df
# Out:
# Weighted Normalized decision matrix:
#           0         1         2   ...        69        70        71
# 0   1.029694  1.033294  0.974338  ...  0.990419  1.009109  1.020019
# 1   1.000000  1.012158  0.986470  ...  0.974792  1.023201  1.034914
# 2   1.015186  1.006625  0.996012  ...  0.969115  1.005552  1.032011
# 3   1.000189  1.000972  0.978832  ...  0.971293  1.031185  1.025968
# 4   1.002460  1.031380  0.975050  ...  0.973614  1.007056  1.017552
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  1.001803  1.029694  0.968526  ...  0.968147  1.001613  1.023960
# 91  1.004647  1.001175  0.972707  ...  0.970160  1.015570  1.030169
# 92  1.025588  1.016990  0.982751  ...  0.979113  1.008745  1.014570
# 93  1.009674  1.004130  0.969216  ...  0.975103  1.003442  1.022124
# 94  1.004647  1.005742  0.969944  ...  0.977512  1.009109  1.025588
#
# [95 rows x 72 columns]

# %%
df["Pi"] = df.prod(axis=1)
print("Precedence Score:")
df
# Out:
# Precedence Score:
#            0         1         2  ...        70        71        Pi
# 0   1.029694  1.033294  0.974338  ...  1.009109  1.020019  0.615164
# 1   1.000000  1.012158  0.986470  ...  1.023201  1.034914  0.617887
# 2   1.015186  1.006625  0.996012  ...  1.005552  1.032011  0.573433
# 3   1.000189  1.000972  0.978832  ...  1.031185  1.025968  0.588175
# 4   1.002460  1.031380  0.975050  ...  1.007056  1.017552  0.581574
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  1.001803  1.029694  0.968526  ...  1.001613  1.023960  0.570725
# 91  1.004647  1.001175  0.972707  ...  1.015570  1.030169  0.564155
# 92  1.025588  1.016990  0.982751  ...  1.008745  1.014570  0.638013
# 93  1.009674  1.004130  0.969216  ...  1.003442  1.022124  0.579401
# 94  1.004647  1.005742  0.969944  ...  1.009109  1.025588  0.563106
#
# [95 rows x 73 columns]

# %%
df['Rank'] = df['Pi'].rank(ascending = 1) 
df
# Out:
#            0         1         2         3  ...        70        71        Pi  Rank
# 0   1.029694  1.033294  0.974338  0.973335  ...  1.009109  1.020019  0.615164  60.0
# 1   1.000000  1.012158  0.986470  0.995587  ...  1.023201  1.034914  0.617887  62.0
# 2   1.015186  1.006625  0.996012  0.972630  ...  1.005552  1.032011  0.573433  20.0
# 3   1.000189  1.000972  0.978832  0.994384  ...  1.031185  1.025968  0.588175  39.0
# 4   1.002460  1.031380  0.975050  0.970714  ...  1.007056  1.017552  0.581574  30.0
# ..       ...       ...       ...       ...  ...       ...       ...       ...   ...
# 90  1.001803  1.029694  0.968526  0.977895  ...  1.001613  1.023960  0.570725  18.0
# 91  1.004647  1.001175  0.972707  0.974869  ...  1.015570  1.030169  0.564155  15.0
# 92  1.025588  1.016990  0.982751  0.985440  ...  1.008745  1.014570  0.638013  76.0
# 93  1.009674  1.004130  0.969216  0.978954  ...  1.003442  1.022124  0.579401  26.0
# 94  1.004647  1.005742  0.969944  0.995587  ...  1.009109  1.025588  0.563106  14.0
#
# [95 rows x 74 columns]

# %%
df = df.set_index('Rank')
df = df.sort_index() 
print("Rank: ")
df
# Out:
# Rank:
#              0         1         2  ...        70        71        Pi
# Rank                                ...
# 1.0   1.008581  1.012158  0.987354  ...  1.005552  1.007120  0.493474
# 2.0   1.002238  1.003389  0.972403  ...  1.002271  1.016862  0.501135
# 3.0   1.008936  1.024448  0.969216  ...  1.004993  1.021626  0.511683
# 4.0   1.003632  1.006625  0.965709  ...  1.001401  1.013716  0.519066
# 5.0   1.001590  1.005183  0.975422  ...  1.012904  1.031250  0.526435
# ...        ...       ...       ...  ...       ...       ...       ...
# 91.0  1.006932  1.011279  0.971532  ...  1.000986  1.035313  0.671149
# 92.0  1.014102  1.000189  0.984118  ...  1.009867  1.026338  0.675037
# 93.0  1.002238  1.019063  0.978355  ...  1.016798  1.010797  0.679891
# 94.0  1.014633  1.033294  0.988301  ...  1.002497  1.032497  0.693975
# 95.0  1.003632  1.023395  0.997861  ...  1.006742  1.022605  0.711854
#
# [95 rows x 73 columns]

# %% [markdown]
# # **Text Book Sum-**

# %%
af = pd.DataFrame(columns = ["VC", "CF", "PI"])
af["VC"] = [710,900,1630,1720,120,160]
af["CF"] = [400,415,440,235,1150,1750]
af["PI"] = [28,38,59,43,8,19]
print("Book Sum Dataset:")
af
# Out:
# Book Sum Dataset:
#      VC    CF  PI
# 0   710   400  28
# 1   900   415  38
# 2  1630   440  59
# 3  1720   235  43
# 4   120  1150   8
# 5   160  1750  19

# %%
w=1
weights=w/3
print("Weights are (wi): ",weights)
# Out:
# Weights are (wi):  0.3333333333333333

# %%
vcmax = int(af["VC"].max())
cfmin = int(af["CF"].min())
pimin = int(af["PI"].min())
print("Min-Max values:")
print("Max of VC: ",vcmax)
print("Min of CF: ",cfmin)
print("Min of PI: ",pimin)
# Out:
# Min-Max values:
# Max of VC:  1720
# Min of CF:  235
# Min of PI:  8

# %%
af["VC"] = vcmax/af["VC"]
af["CF"] = cfmin/af["CF"]
af["PI"] = pimin/af["PI"]
print("Normalized matrix:")
af
# Out:
# Normalized matrix:
#           VC        CF        PI
# 0   2.422535  0.587500  0.285714
# 1   1.911111  0.566265  0.210526
# 2   1.055215  0.534091  0.135593
# 3   1.000000  1.000000  0.186047
# 4  14.333333  0.204348  1.000000
# 5  10.750000  0.134286  0.421053

# %%
af = af**wi
print("Weighted Normalized decision matrix:")
af
# Out:
# Weighted Normalized decision matrix:
#          VC        CF        PI
# 0  1.012365  0.992640  0.982751
# 1  1.009036  0.992133  0.978592
# 2  1.000747  0.991327  0.972630
# 3  1.000000  1.000000  0.976913
# 4  1.037673  0.978187  1.000000
# 5  1.033535  0.972499  0.988058

# %%
af["Pi"] = af.prod(axis=1)
print("Precedence Score:")
af
# Out:
# Precedence Score:
#          VC        CF        PI        Pi
# 0  1.012365  0.992640  0.982751  0.987580
# 1  1.009036  0.992133  0.978592  0.979666
# 2  1.000747  0.991327  0.972630  0.964914
# 3  1.000000  1.000000  0.976913  0.976913
# 4  1.037673  0.978187  1.000000  1.015038
# 5  1.033535  0.972499  0.988058  0.993109

# %%
af['Rank'] = af['Pi'].rank(ascending = 1) 
af
# Out:
#          VC        CF        PI        Pi  Rank
# 0  1.012365  0.992640  0.982751  0.987580   4.0
# 1  1.009036  0.992133  0.978592  0.979666   3.0
# 2  1.000747  0.991327  0.972630  0.964914   1.0
# 3  1.000000  1.000000  0.976913  0.976913   2.0
# 4  1.037673  0.978187  1.000000  1.015038   6.0
# 5  1.033535  0.972499  0.988058  0.993109   5.0

# %%
af = af.set_index('Rank')
af = af.sort_index() 
print("Rank: ")
af
# Out:
# Rank:
#             VC        CF        PI        Pi
# Rank
# 1.0   1.000747  0.991327  0.972630  0.964914
# 2.0   1.000000  1.000000  0.976913  0.976913
# 3.0   1.009036  0.992133  0.978592  0.979666
# 4.0   1.012365  0.992640  0.982751  0.987580
# 5.0   1.033535  0.972499  0.988058  0.993109
# 6.0   1.037673  0.978187  1.000000  1.015038
