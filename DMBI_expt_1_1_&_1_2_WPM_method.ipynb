# %% [markdown]
# Anisha Gharat
#
# BE Comps Batch E
#
# Roll no.: 68
#
# UID: 2018230071

# %% [markdown]
# # **WPM method**

# %%
RN = 68
N=93+RN%11
print("No. of Alternatives (N):",N)
M=70+RN%11
print("No. of Attributes (M):",M)
# Out:
# No. of Alternatives (N): 95
# No. of Attributes (M): 72

# %%
w=1
wi=w/M
print("Weights are (wi): ",wi)
# Out:
# Weights are (wi):  0.013888888888888888

# %%
lrange = RN//11
print("Start range: ",lrange)
rrange = RN+RN/11
print("End range: ",rrange)
# Out:
# Start range:  6
# End range:  74.18181818181819

# %%
import numpy as np
import pandas as pd

data = np.random.randint(lrange, rrange+1, size=(N, M))
df = pd.DataFrame(data, columns=[i for i in range(0,M)])
print("Dataset:")
df
# Out:
# Dataset:
#     0   1   2   3   4   5   6   7   8   ...  63  64  65  66  67  68  69  70  71
# 0   49  38  37   7  58  16  52  39  67  ...  28  22  43  25  45  60  56  53  56
# 1   18  22  27  53  32  49  33  60  13  ...  32   7  56  30  55  67  44  36   8
# 2   54  44  61  52  66  52   9  15  60  ...  20  48  15  64  36  20  50  16  50
# 3   10  42  36  17  59  15  41  11  71  ...  62  68  50  36  17  12  41  60  32
# 4   47  72  43  14  50  58  37  23  42  ...  68  41   6  15  44  51   7  68  32
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 90  39  74  37  13  39  44  57  73  29  ...  55  19  46  26  22  19  16  16  19
# 91  54   8  43  15  31  29  73  35  20  ...  50  26  17  51  19  24  54  22  59
# 92  21  36  66  67  63  67  17  21  57  ...  36  44   7  44  43  62   7  66  29
# 93  57  63  67  33  71  62  30  40  44  ...  69  19  49  38  62  68  57  74  42
# 94  52  14  32  46  25  64  16   7  42  ...   9  19  64  71  45  56  69  54  40
#
# [95 rows x 72 columns]

# %%
B = M//2
NB = M//2
print("No. of beneficial attributes (B) =",B)
print("No. of non-beneficial attributes (NB) =",NB)
# Out:
# No. of beneficial attributes (B) = 36
# No. of non-beneficial attributes (NB) = 36

# %%
arr=[]
for i in range(0,M):
  arr.append(i)

Bdata = np.random.randint(0,72,size=B)
for i in range(0, len(Bdata)):
  if Bdata[i] in arr:
    arr.remove(Bdata[i])

print("Beneficial Attributes: ")
print(Bdata)
print()
print("Non-Beneficial Attributes: ",arr)
# Out:
# Beneficial Attributes:
# [37 66  5 24 36 70 17  1 31 13 16 59 33 50 59 42 34 40 65 39 50 68 60  4
#  60  0 39 40 13 22 38 65 65  9  7 68]
#
# Non-Beneficial Attributes:  [2, 3, 6, 8, 10, 11, 12, 14, 15, 18, 19, 20, 21, 23, 25, 26, 27, 28, 29, 30, 32, 35, 41, 43, 44, 45, 46, 47, 48, 49, 51, 52, 53, 54, 55, 56, 57, 58, 61, 62, 63, 64, 67, 69, 71]

# %%
for i in arr:
  column = df[i]
  minval = column.min()
  df[i] = minval/df[i]

# %%
for i in Bdata:
  column = df[i]
  maxval = column.max()
  df[i] = df[i]/maxval

# %%
print("Normalized matrix:")
df
# Out:
# Normalized matrix:
#           0         1         2   ...        69        70        71
# 0   0.662162  0.513514  0.162162  ...  0.125000  0.716216  0.125000
# 1   0.243243  0.297297  0.222222  ...  0.159091  0.486486  0.875000
# 2   0.729730  0.594595  0.098361  ...  0.140000  0.216216  0.140000
# 3   0.135135  0.567568  0.166667  ...  0.170732  0.810811  0.218750
# 4   0.635135  0.972973  0.139535  ...  1.000000  0.918919  0.218750
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  0.527027  1.000000  0.162162  ...  0.437500  0.216216  0.368421
# 91  0.729730  0.108108  0.139535  ...  0.129630  0.297297  0.118644
# 92  0.283784  0.486486  0.090909  ...  1.000000  0.891892  0.241379
# 93  0.770270  0.851351  0.089552  ...  0.122807  1.000000  0.166667
# 94  0.702703  0.189189  0.187500  ...  0.101449  0.729730  0.175000
#
# [95 rows x 72 columns]

# %%
df = df**wi
print("Weighted Normalized decision matrix:")
df
# Out:
# Weighted Normalized decision matrix:
#           0         1         2   ...        69        70        71
# 0   0.994291  0.990786  0.975050  ...  0.971532  0.995375  0.971532
# 1   0.980557  0.983294  0.979327  ...  0.974792  0.990042  0.998147
# 2   0.995633  0.992806  0.968303  ...  0.973062  0.978954  0.973062
# 3   0.972584  0.992164  0.975422  ...  0.975748  0.997091  0.979113
# 4   0.993715  0.999620  0.973017  ...  1.000000  0.998826  0.979113
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  0.991144  1.000000  0.975050  ...  0.988584  0.978954  0.986227
# 91  0.995633  0.969575  0.973017  ...  0.972023  0.983294  0.970828
# 92  0.982658  0.990042  0.967244  ...  1.000000  0.998412  0.980452
# 93  0.996381  0.997767  0.967042  ...  0.971293  1.000000  0.975422
# 94  0.995112  0.977140  0.977019  ...  0.968719  0.995633  0.976083
#
# [95 rows x 72 columns]

# %%
df["Ai"] = df.prod(axis=1)
print("Precedence Score:")
df
# Out:
# Precedence Score:
#            0         1         2  ...        70        71        Ai
# 0   0.994291  0.990786  0.975050  ...  0.995375  0.971532  0.266459
# 1   0.980557  0.983294  0.979327  ...  0.990042  0.998147  0.269169
# 2   0.995633  0.992806  0.968303  ...  0.978954  0.973062  0.259412
# 3   0.972584  0.992164  0.975422  ...  0.997091  0.979113  0.256546
# 4   0.993715  0.999620  0.973017  ...  0.998826  0.979113  0.252427
# ..       ...       ...       ...  ...       ...       ...       ...
# 90  0.991144  1.000000  0.975050  ...  0.978954  0.986227  0.259624
# 91  0.995633  0.969575  0.973017  ...  0.983294  0.970828  0.221591
# 92  0.982658  0.990042  0.967244  ...  0.998412  0.980452  0.265898
# 93  0.996381  0.997767  0.967042  ...  1.000000  0.975422  0.261039
# 94  0.995112  0.977140  0.977019  ...  0.995633  0.976083  0.270582
#
# [95 rows x 73 columns]

# %%
df['Rank'] = df['Ai'].rank(ascending = 0) 
df
# Out:
#            0         1         2         3  ...        70        71        Ai  Rank
# 0   0.994291  0.990786  0.975050  0.997861  ...  0.995375  0.971532  0.266459  45.0
# 1   0.980557  0.983294  0.979327  0.970196  ...  0.990042  0.998147  0.269169  37.0
# 2   0.995633  0.992806  0.968303  0.970452  ...  0.978954  0.973062  0.259412  58.0
# 3   0.972584  0.992164  0.975422  0.985639  ...  0.997091  0.979113  0.256546  61.0
# 4   0.993715  0.999620  0.973017  0.988301  ...  0.998826  0.979113  0.252427  67.0
# ..       ...       ...       ...       ...  ...       ...       ...       ...   ...
# 90  0.991144  1.000000  0.975050  0.989319  ...  0.978954  0.986227  0.259624  57.0
# 91  0.995633  0.969575  0.973017  0.987354  ...  0.983294  0.970828  0.221591  95.0
# 92  0.982658  0.990042  0.967244  0.967042  ...  0.998412  0.980452  0.265898  47.0
# 93  0.996381  0.997767  0.967042  0.976601  ...  1.000000  0.975422  0.261039  53.0
# 94  0.995112  0.977140  0.977019  0.972106  ...  0.995633  0.976083  0.270582  32.0
#
# [95 rows x 74 columns]

# %%
df = df.set_index('Rank')
df = df.sort_index() 
print("Rank: ")
df
# Out:
# Rank:
#              0         1         2  ...        70        71        Ai
# Rank                                ...
# 1.0   0.987538  0.993715  0.977449  ...  0.999228  0.979991  0.325262
# 2.0   0.980557  0.994570  0.982116  ...  0.994843  0.996516  0.321578
# 3.0   0.999228  0.996136  0.972403  ...  0.971162  0.980930  0.303123
# 4.0   0.994006  0.977140  0.965709  ...  0.996381  0.984857  0.301588
# 5.0   0.997320  1.000000  0.967449  ...  0.977140  0.982475  0.300812
# ...        ...       ...       ...  ...       ...       ...       ...
# 91.0  0.990419  0.971162  0.967658  ...  0.997767  0.971532  0.229483
# 92.0  0.992489  0.972584  0.969944  ...  0.996622  0.977140  0.229226
# 93.0  0.975050  0.990786  0.972707  ...  0.985578  0.981940  0.227812
# 94.0  0.986593  0.978954  0.986470  ...  0.965709  0.984857  0.223023
# 95.0  0.995633  0.969575  0.973017  ...  0.983294  0.970828  0.221591
#
# [95 rows x 73 columns]

# %% [markdown]
# # **Text Book Sum-**

# %%
af = pd.DataFrame(columns = ["VC", "CF", "PI"])
af["VC"] = [710,900,1630,1720,120,160]
af["CF"] = [400,415,440,235,1150,1750]
af["PI"] = [28,38,59,43,8,19]
print("Book Sum Dataset:")
af
# Out:
# Book Sum Dataset:
#      VC    CF  PI
# 0   710   400  28
# 1   900   415  38
# 2  1630   440  59
# 3  1720   235  43
# 4   120  1150   8
# 5   160  1750  19

# %%
w1=0.7142
w2=0.1429
w3=0.1429

# %% [markdown]
# **VC is a beneficial attribute and CF & PI are non-beneficial attributes**

# %%
vcmax = int(af["VC"].max())
cfmin = int(af["CF"].min())
pimin = int(af["PI"].min())
print("Min-Max values:")
print("Max of VC: ",vcmax)
print("Min of CF: ",cfmin)
print("Min of PI: ",pimin)
# Out:
# Min-Max values:
# Max of VC:  1720
# Min of CF:  235
# Min of PI:  8

# %%
af["VC"] = af["VC"]/vcmax
af["CF"] = cfmin/af["CF"]
af["PI"] = pimin/af["PI"]
print("Normalized matrix:")
af
# Out:
# Normalized matrix:
#          VC        CF        PI
# 0  0.412791  0.587500  0.285714
# 1  0.523256  0.566265  0.210526
# 2  0.947674  0.534091  0.135593
# 3  1.000000  1.000000  0.186047
# 4  0.069767  0.204348  1.000000
# 5  0.093023  0.134286  0.421053

# %%
af['VC'] = af['VC']**w1
af['CF'] = af['CF']**w2
af['PI'] = af['PI']**w3
print("Weighted Normalized decision matrix:")
af
# Out:
# Weighted Normalized decision matrix:
#          VC        CF        PI
# 0  0.531562  0.926811  0.836089
# 1  0.629659  0.921948  0.800388
# 2  0.962343  0.914274  0.751617
# 3  1.000000  1.000000  0.786374
# 4  0.149326  0.796988  1.000000
# 5  0.183387  0.750577  0.883726

# %%
af["Ai"] = af.prod(axis=1)
print("Precedence Score:")
af
# Out:
# Precedence Score:
#          VC        CF        PI        Ai
# 0  0.531562  0.926811  0.836089  0.411906
# 1  0.629659  0.921948  0.800388  0.464636
# 2  0.962343  0.914274  0.751617  0.661307
# 3  1.000000  1.000000  0.786374  0.786374
# 4  0.149326  0.796988  1.000000  0.119011
# 5  0.183387  0.750577  0.883726  0.121641

# %%
af['Rank'] = af['Ai'].rank(ascending = 0) 
af
# Out:
#          VC        CF        PI        Ai  Rank
# 0  0.531562  0.926811  0.836089  0.411906   4.0
# 1  0.629659  0.921948  0.800388  0.464636   3.0
# 2  0.962343  0.914274  0.751617  0.661307   2.0
# 3  1.000000  1.000000  0.786374  0.786374   1.0
# 4  0.149326  0.796988  1.000000  0.119011   6.0
# 5  0.183387  0.750577  0.883726  0.121641   5.0

# %%
af = af.set_index('Rank')
af = af.sort_index() 
print("Rank: ")
af
# Out:
# Rank:
#             VC        CF        PI        Ai
# Rank
# 1.0   1.000000  1.000000  0.786374  0.786374
# 2.0   0.962343  0.914274  0.751617  0.661307
# 3.0   0.629659  0.921948  0.800388  0.464636
# 4.0   0.531562  0.926811  0.836089  0.411906
# 5.0   0.183387  0.750577  0.883726  0.121641
# 6.0   0.149326  0.796988  1.000000  0.119011

# %% [markdown]
# **W4 is the best choice.**
