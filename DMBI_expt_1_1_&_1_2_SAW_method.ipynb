# %% [markdown]
# Anisha Gharat
#
# BE Comps Batch E
#
# Roll no.: 68
#
# UID: 2018230071

# %% [markdown]
# # **SAW method**

# %%
RN = 68
N=93+RN%11
print("No. of Alternatives (N):",N)
M=70+RN%11
print("No. of Attributes (M):",M)
# Out:
# No. of Alternatives (N): 95
# No. of Attributes (M): 72

# %%
w=1
wi=w/M
print("Weights are (wi): ",wi)
# Out:
# Weights are (wi):  0.013888888888888888

# %%
lrange = RN//11
print("Start range: ",lrange)
rrange = RN+RN/11
print("End range: ",rrange)
# Out:
# Start range:  6
# End range:  74.18181818181819

# %%
import numpy as np
import pandas as pd

data = np.random.randint(lrange, rrange+1, size=(N, M))
df = pd.DataFrame(data, columns=[i for i in range(0,M)])
print("Dataset:")
df
# Out:
# Dataset:
#     0   1   2   3   4   5   6   7   8   ...  63  64  65  66  67  68  69  70  71
# 0   59  49  14  68  63  66  14  28  57  ...  26   9  54  67  48  13  50  57  53
# 1   34  28  55  45  56   9  20  71  24  ...  28  51  39  61  65  10  26  66  18
# 2    7  72  59  66  17  28  26  35  44  ...   9  56  49  14  32  44  24  70  41
# 3   67  10  55  14  65  31  14  28  52  ...  57  22  42  66  23  50   7  33  68
# 4   48  55  16  34  30  55  17  14  40  ...  58  68  13   9   8  62  32  22  46
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 90  30  57  32  33  28  37  44  33  19  ...  69  49  27  21  16  30  34  46  31
# 91  42  30  46  74  67  57  15  28  52  ...  25  58  36  49  21  24  68  18  56
# 92   9  55  15  59  55  30  37  61  34  ...  51  74  43  30   6  69  67  18  22
# 93  65  73  19  69  69  13   6  47  18  ...  71  17  59  61  43  23  73  14  34
# 94  13  21  35  53  14  71  35  17  17  ...  73  59  23  24  36  64  12  28  50
#
# ...

# %%
B = M//2
NB = M//2
print("No. of beneficial attributes (B) =",B)
print("No. of non-beneficial attributes (NB) =",NB)
# Out:
# No. of beneficial attributes (B) = 36
# No. of non-beneficial attributes (NB) = 36

# %%
arr=[]
for i in range(0,M):
  arr.append(i)

Bdata = np.random.randint(0,72,size=B)
#bdf = pd.DataFrame(Bdata, columns=['Beneficial Attributes'])

for i in range(0, len(Bdata)):
  if Bdata[i] in arr:
    arr.remove(Bdata[i])

print("Beneficial Attributes: ")
print(Bdata)
print()
print("Non-Beneficial Attributes: ",arr)
#nbdf = pd.DataFrame(arr, columns=['Non-Beneficial Attributes'])
# Out:
# Beneficial Attributes:
# [34 12 17 22 41 25  0 47 53 67 69 17 47 32 42  2 58 11 28 67 69 63 14 10
#  22 23  5 29 55 41  6 39 18 48 70 56]
#
# Non-Beneficial Attributes:  [1, 3, 4, 7, 8, 9, 13, 15, 16, 19, 20, 21, 24, 26, 27, 30, 31, 33, 35, 36, 37, 38, 40, 43, 44, 45, 46, 49, 50, 51, 52, 54, 57, 59, 60, 61, 62, 64, 65, 66, 68, 71]

# %%
for i in arr:
  column = df[i]
  minval = column.min()
  #print(minval)
  df[i] = minval/df[i]
  # print(df[i])

# %%
for i in Bdata:
  column = df[i]
  maxval = column.max()
  #print(maxval)
  df[i] = maxval/df[i]
  # print(df[i])

# %%
print("Normalized matrix:")
df
# Out:
# Normalized matrix:
#            0         1         2   ...         69        70        71
# 0    1.220339  0.122449  5.214286  ...   8.333333  1.280702  0.113208
# 1    2.117647  0.214286  1.327273  ...   4.333333  1.106061  0.333333
# 2   10.285714  0.083333  1.237288  ...   4.000000  1.042857  0.146341
# 3    1.074627  0.600000  1.327273  ...   1.166667  2.212121  0.088235
# 4    1.500000  0.109091  4.562500  ...   5.333333  3.318182  0.130435
# ..        ...       ...       ...  ...        ...       ...       ...
# 90   2.400000  0.105263  2.281250  ...   5.666667  1.586957  0.193548
# 91   1.714286  0.200000  1.586957  ...  11.333333  4.055556  0.107143
# 92   8.000000  0.109091  4.866667  ...  11.166667  4.055556  0.272727
# 93   1.107692  0.082192  3.842105  ...  12.166667  5.214286  0.176471
# 94   5.538462  0.285714  2.085714  ...   2.000000  2.607143  0.120000
#
# [95 rows x 72 columns]

# %%
df["sum"] = df.sum(axis=1)
df["Pi"] = df["sum"]*wi
print("Weighted normalized decision matrix : Calculation of Pi")
df
# Out:
# Weighted normalized decision matrix : Calculation of Pi
#             0         1         2  ...        71         sum        Pi
# 0    1.220339  0.122449  5.214286  ...  0.113208  106.507074  1.479265
# 1    2.117647  0.214286  1.327273  ...  0.333333  131.060979  1.820291
# 2   10.285714  0.083333  1.237288  ...  0.146341  123.698296  1.718032
# 3    1.074627  0.600000  1.327273  ...  0.088235  108.809269  1.511240
# 4    1.500000  0.109091  4.562500  ...  0.130435  107.349448  1.490965
# ..        ...       ...       ...  ...       ...         ...       ...
# 90   2.400000  0.105263  2.281250  ...  0.193548   98.531737  1.368496
# 91   1.714286  0.200000  1.586957  ...  0.107143  122.192622  1.697120
# 92   8.000000  0.109091  4.866667  ...  0.272727  113.942046  1.582528
# 93   1.107692  0.082192  3.842105  ...  0.176471  138.257749  1.920247
# 94   5.538462  0.285714  2.085714  ...  0.120000   79.051363  1.097936
#
# [95 rows x 74 columns]

# %%
df['Rank'] = df['Pi'].rank(ascending = 1) 
df
# Out:
#             0         1         2  ...         sum        Pi  Rank
# 0    1.220339  0.122449  5.214286  ...  106.507074  1.479265  26.0
# 1    2.117647  0.214286  1.327273  ...  131.060979  1.820291  82.0
# 2   10.285714  0.083333  1.237288  ...  123.698296  1.718032  68.0
# 3    1.074627  0.600000  1.327273  ...  108.809269  1.511240  30.0
# 4    1.500000  0.109091  4.562500  ...  107.349448  1.490965  28.0
# ..        ...       ...       ...  ...         ...       ...   ...
# 90   2.400000  0.105263  2.281250  ...   98.531737  1.368496  14.0
# 91   1.714286  0.200000  1.586957  ...  122.192622  1.697120  65.0
# 92   8.000000  0.109091  4.866667  ...  113.942046  1.582528  41.0
# 93   1.107692  0.082192  3.842105  ...  138.257749  1.920247  93.0
# 94   5.538462  0.285714  2.085714  ...   79.051363  1.097936   1.0
#
# [95 rows x 75 columns]

# %%
df = df.set_index('Rank')
df = df.sort_index() 
print("Rank: ")
df
# Out:
# Rank:
#              0         1         2  ...        71         sum        Pi
# Rank                                ...
# 1.0   5.538462  0.285714  2.085714  ...  0.120000   79.051363  1.097936
# 2.0   1.531915  0.222222  2.807692  ...  0.125000   84.617512  1.175243
# 3.0   1.220339  0.222222  2.147059  ...  0.171429   91.213385  1.266853
# 4.0   1.800000  0.093750  4.294118  ...  0.315789   91.460596  1.270286
# 5.0   2.117647  0.750000  8.111111  ...  0.162162   91.705994  1.273694
# ...        ...       ...       ...  ...       ...         ...       ...
# 91.0  4.000000  0.750000  1.158730  ...  0.200000  136.779476  1.899715
# 92.0  1.074627  0.109091  4.866667  ...  0.162162  137.094207  1.904086
# 93.0  1.107692  0.082192  3.842105  ...  0.176471  138.257749  1.920247
# 94.0  1.107692  0.113208  4.562500  ...  0.750000  139.502183  1.937530
# 95.0  6.545455  0.089552  4.866667  ...  0.222222  155.136287  2.154671
#
# [95 rows x 74 columns]

# %% [markdown]
# # **Text Book Sum-**

# %%
af = pd.DataFrame(columns = ["VC", "CF", "PI"])
af["VC"] = [710,900,1630,1720,120,160]
af["CF"] = [400,415,440,235,1150,1750]
af["PI"] = [28,38,59,43,8,19]
print("Book Sum Dataset:")
af
# Out:
# Book Sum Dataset:
#      VC    CF  PI
# 0   710   400  28
# 1   900   415  38
# 2  1630   440  59
# 3  1720   235  43
# 4   120  1150   8
# 5   160  1750  19

# %%
w=1
weights=w/3
print("Weights are (wi): ",weights)
# Out:
# Weights are (wi):  0.3333333333333333

# %% [markdown]
# **VC is a beneficial attribute and CF & PI are non-beneficial attributes**

# %%
vcmax = int(af["VC"].max())
cfmin = int(af["CF"].min())
pimin = int(af["PI"].min())
print("Min-Max values:")
print("Max of VC: ",vcmax)
print("Min of CF: ",cfmin)
print("Min of PI: ",pimin)
# Out:
# Min-Max values:
# Max of VC:  1720
# Min of CF:  235
# Min of PI:  8

# %%
af["VC"] = vcmax/af["VC"]
af["CF"] = cfmin/af["CF"]
af["PI"] = pimin/af["PI"]
print("Normalized matrix:")
af
# Out:
# Normalized matrix:
#           VC        CF        PI
# 0   2.422535  0.587500  0.285714
# 1   1.911111  0.566265  0.210526
# 2   1.055215  0.534091  0.135593
# 3   1.000000  1.000000  0.186047
# 4  14.333333  0.204348  1.000000
# 5  10.750000  0.134286  0.421053

# %%
af["sum"] = af.sum(axis=1)
af["Pi"] = af["sum"]*wi
print("Weighted normalized decision matrix : Calculation of Pi")
af
# Out:
# Weighted normalized decision matrix : Calculation of Pi
#           VC        CF        PI        sum        Pi
# 0   2.422535  0.587500  0.285714   3.295749  0.045774
# 1   1.911111  0.566265  0.210526   2.687902  0.037332
# 2   1.055215  0.534091  0.135593   1.724899  0.023957
# 3   1.000000  1.000000  0.186047   2.186047  0.030362
# 4  14.333333  0.204348  1.000000  15.537681  0.215801
# 5  10.750000  0.134286  0.421053  11.305338  0.157019

# %%
af['Rank'] = af['Pi'].rank(ascending = 1) 
af
# Out:
#           VC        CF        PI        sum        Pi  Rank
# 0   2.422535  0.587500  0.285714   3.295749  0.045774   4.0
# 1   1.911111  0.566265  0.210526   2.687902  0.037332   3.0
# 2   1.055215  0.534091  0.135593   1.724899  0.023957   1.0
# 3   1.000000  1.000000  0.186047   2.186047  0.030362   2.0
# 4  14.333333  0.204348  1.000000  15.537681  0.215801   6.0
# 5  10.750000  0.134286  0.421053  11.305338  0.157019   5.0

# %%
af = af.set_index('Rank')
af = af.sort_index() 
print("Rank: ")
af
# Out:
# Rank:
#              VC        CF        PI        sum        Pi
# Rank
# 1.0    1.055215  0.534091  0.135593   1.724899  0.023957
# 2.0    1.000000  1.000000  0.186047   2.186047  0.030362
# 3.0    1.911111  0.566265  0.210526   2.687902  0.037332
# 4.0    2.422535  0.587500  0.285714   3.295749  0.045774
# 5.0   10.750000  0.134286  0.421053  11.305338  0.157019
# 6.0   14.333333  0.204348  1.000000  15.537681  0.215801
